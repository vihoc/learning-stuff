# %%
 from tensorflow.keras.models import load_model

# %%
model = load_model('cnn approach 22.h5')
model.summary()
# Out:
# 2025-09-18 15:57:13.140889: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-09-18 15:57:13.140912: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-09-18 15:57:13.140920: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-09-18 15:57:13.140958: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-09-18 15:57:13.140973: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "model"
# __________________________________________________________________________________________________
# ...

# %%
model = load_model('cnn approach 18.h5')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_2 (InputLayer)        [(None, 96, 96, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 96, 96, 32)           864       ['input_2[0][0]']
#
#  batch_normalization (Batch  (None, 96, 96, 32)           128       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 96, 96, 32)           0         ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 64)           18432     ['activation[0][0]']
#
#  batch_normalization_2 (Bat  (None, 48, 48, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 48, 48, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
# ...

# %%
model = load_model('cnn approach 10.h5')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_2 (InputLayer)        [(None, 96, 96, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 96, 96, 32)           864       ['input_2[0][0]']
#
#  batch_normalization (Batch  (None, 96, 96, 32)           128       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 96, 96, 32)           0         ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 64)           18432     ['activation[0][0]']
#
#  batch_normalization_2 (Bat  (None, 48, 48, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 48, 48, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
# ...

# %%
model = load_model('cnn approach 11.h5')
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 96, 96, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 96, 96, 32)           896       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 96, 96, 32)           128       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 96, 96, 32)           0         ['batch_normalization[0][0]']
#
#  separable_conv2d (Separabl  (None, 96, 96, 32)           1344      ['activation[0][0]']
#  eConv2D)
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 32)           1056      ['activation[0][0]']
#
#  separable_conv2d_1 (Separa  (None, 96, 96, 32)           1344      ['separable_conv2d[0][0]']
#  bleConv2D)
#
#  add (Add)                   (None, 96, 96, 32)           0         ['conv2d_1[0][0]',
# ...

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, SeparableConv2D, BatchNormalization, Activation,
    Add, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
)

# Input layer
input_layer = Input(shape=(96, 96, 3))

# Initial Conv block
x = Conv2D(32, (3, 3), padding='same')(input_layer)
x = BatchNormalization()(x)
x = Activation('relu')(x)

# Residual block with separable conv
sep1 = SeparableConv2D(32, (3, 3), padding='same')(x)
conv1 = Conv2D(32, (3, 3), padding='same')(x)
sep2 = SeparableConv2D(32, (3, 3), padding='same')(sep1)
x = Add()([conv1, sep2])
x = BatchNormalization()(x)
x = Activation('relu')(x)

# Downsampling
x = MaxPooling2D(pool_size=(2, 2))(x)

# Conv block 2
x = Conv2D(64, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Conv block 3
x = Conv2D(128, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Global pooling and dense layers
x = GlobalAveragePooling2D()(x)
x = Dense(128)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid')(x)

# Build model
model = Model(inputs=input_layer, outputs=output)
